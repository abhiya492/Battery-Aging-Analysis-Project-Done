# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Battery Aging Analysis Notebook\n",
    "\n",
    "## Project Overview\n",
    "This notebook provides an interactive exploration of battery aging datasets."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Import required libraries\n",
    "import sys\n",
    "import os\n",
    "import pandas as pd\n",
    "import numpy as np\n",
    "import plotly.express as px\n",
    "import plotly.graph_objects as go\n",
    "\n",
    "# Add project root to path\n",
    "project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))\n",
    "sys.path.insert(0, project_root)"
   ],
   "outputs": []
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Import project modules\n",
    "from src.data_loader import BatteryDataLoader\n",
    "from src.data_preprocessing import BatteryDataPreprocessor\n",
    "from src.visualization import BatteryAgingVisualizer"
   ],
   "outputs": []
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Load data\n",
    "data_loader = BatteryDataLoader('data/cleaned_dataset/data')\n",
    "combined_data = data_loader.combine_datasets()"
   ],
   "outputs": []
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Preprocess data\n",
    "preprocessor = BatteryDataPreprocessor()\n",
    "cleaned_data = preprocessor.clean_data(combined_data)"
   ],
   "outputs": []
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "source": [
    "# Interactive exploration\n",
    "def explore_battery_data(df):\n",
    "    # Basic statistics\n",
    "    print(df.describe())\n    \n    # Create interactive plots\n    fig_impedance = px.scatter(\n        df, x='Cycle', y='Battery_impedance', \n        color='Temperature', \n        title='Battery Impedance over Cycles'\n    )\n    fig_impedance.show()\n    \n    fig_rct = px.scatter(\n        df, x='Cycle', y='Rct', \n        color='Temperature', \n        title='Charge Transfer Resistance over Cycles'\n    )\n    fig_rct.show()\n\n# Explore the data\nexplore_battery_data(cleaned_data)"
   ],
   "outputs": []
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Battery Aging Analysis Notebook\n",
#       8     "\n",
#       9     "## Project Overview\n",
#      10     "This notebook provides an interactive exploration of battery aging datasets."
#      11    ]
#      12   },
#      13   {
#      14    "cell_type": "code",
# ---> 15    "execution_count": null,
#      16    "metadata": {},
#      17    "source": [
#      18     "# Import required libraries\n",
#      19     "import sys\n",
#      20     "import os\n",
#      21     "import pandas as pd\n",
#      22     "import numpy as np\n",
#      23     "import plotly.express as px\n",
#      24     "import plotly.graph_objects as go\n",
#      25     "\n",
# ...
